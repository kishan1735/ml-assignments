# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,StandardScaler, MinMaxScaler
import numpy as np

# %%
housing_df = pd.read_csv("housing.csv")
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
housing_df.shape[0]
# Out:
# 20640

# %%
housing_stats = housing_df.describe()
housing_stats
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_descriptive_stats(df):
     housing_describe = housing_df.describe() 
     print(housing_describe)  

visualize_descriptive_stats(housing_df)
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing_df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
median_tb = housing_df['total_bedrooms'].median()
unfiltered_housing_df = housing_df
housing_df['total_bedrooms']  = housing_df['total_bedrooms'].fillna(median_tb)

# %%
housing_df.isna().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms        False
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %%
def box_plot(x_val,df):
    plt.figure(figsize=(10, 8))
    sns.boxplot(data=df, x=x_val, palette='viridis')
    plt.show()

# %%
box_plot('total_bedrooms',unfiltered_housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
box_plot('total_bedrooms',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
housing_df.drop_duplicates(inplace=True)
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
plt.figure()
plt.scatter(housing_df['longitude'],housing_df['latitude'],c=housing_df['median_house_value'])
plt.ylabel("latitude")
plt.xlabel("longitude")
plt.title("Housing prices")
plt.colorbar(orientation="vertical") 
plt.show()
plt.close()

# %%
filtered_df = housing_df[(housing_df['total_rooms'] > 1500) & (housing_df['median_income'] > 10)]
print(filtered_df)

plt.subplot(2,2,1)
plt.scatter(filtered_df['longitude'],filtered_df['latitude'],c=filtered_df['median_house_value'])
plt.ylabel("latitude")
plt.xlabel("longitude")
plt.title("Housing prices")
plt.colorbar(orientation="vertical") 
plt.subplot(2,2,2)
plt.scatter(filtered_df['longitude'],filtered_df['latitude'],c=filtered_df['median_income'])
plt.ylabel("latitude")
plt.xlabel("longitude")
plt.title("median income")
plt.colorbar(orientation="vertical") 
plt.tight_layout()
plt.show()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 131      -122.19     37.84                  18         1617           210.0
# 409      -122.28     37.90                  52         2003           250.0
# 510      -122.22     37.82                  39         2492           310.0
# 511      -122.22     37.82                  42         2991           335.0
# 512      -122.23     37.82                  52         3242           366.0
# ...          ...       ...                 ...          ...             ...
# 18361    -122.14     37.36                  23        11294          1377.0
# 18362    -122.15     37.35                  23         3814           485.0
# 20376    -118.86     34.16                  16         1509           216.0
# 20389    -118.90     34.19                  26         1582           196.0
# 20436    -118.69     34.21                  10         3663           409.0
#
# ...

# %%
grouped_df = housing_df.groupby('ocean_proximity')
summary_stats = grouped_df.aggregate(['mean', 'median', 'std'])
summary_stats
# Out:
#                   longitude                      latitude                   \
#                        mean   median       std       mean median       std
# ocean_proximity
# <1H OCEAN       -118.847766 -118.275  1.588888  34.560577  34.03  1.467127
# INLAND          -119.732990 -120.000  1.900950  36.731829  36.97  2.116073
# ISLAND          -118.354000 -118.320  0.070569  33.358000  33.34  0.040866
# NEAR BAY        -122.260694 -122.250  0.147004  37.801057  37.79  0.185434
# NEAR OCEAN      -119.332555 -118.260  2.327307  34.738439  33.79  2.275386
#
#                 housing_median_age                    total_rooms  ...  \
#                               mean median        std         mean  ...
# ocean_proximity                                                    ...
# <1H OCEAN                29.279225   30.0  11.644453  2628.343586  ...
# INLAND                   24.271867   23.0  12.018020  2717.742787  ...
# ...

# %%
def plot_relation(x_val,y_val):
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=x_val, y=y_val, data=housing_df)
    plt.title(f"Distribution of {x_val} Across {y_val}")
    plt.show()

# %%
plot_relation('ocean_proximity', 'median_house_value')

# %%
open_hot_encoded_df = pd.get_dummies(housing_df, columns=['ocean_proximity'], drop_first=True)
open_hot_encoded_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
encoder = LabelEncoder()
housing_df['ocean_proximity'] = encoder.fit_transform(housing_df['ocean_proximity'])
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
corr_matrix = housing_df.corr()
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069120 -0.066484           -0.319026     0.927058
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# ocean_proximity     -0.289779  0.200974            0.112468    -0.015693
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069120    0.099773    0.055310      -0.015176
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
box_plot('total_rooms',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
box_plot('housing_median_age',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
box_plot('total_bedrooms',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
box_plot('latitude',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
box_plot('longitude',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %%
box_plot('population',housing_df)
# Out:
# /tmp/ipykernel_103679/2397121394.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=x_val, palette='viridis')

# %% [markdown]
# ### Positive Correlations:
#
# - **median_income and median_house_value**:
#   - A positive correlation indicating that as household income increases, housing prices increase.
#
# - **total_rooms and population**:
#   - There is a positive correlation between the total number of rooms and the population or number of households. More rooms generally indicate larger houses, accommodating more people.
#
# ### Negative Correlations:
#
# - **latitude and median_house_value**:
#   - A negative correlation between latitude and house prices suggests that homes located further north in the region tend to have lower values.

# %% [markdown]
# ### Outliers
#
# Outliers are observed in **total_rooms**, **total_bedrooms**, **populations**

# %% [markdown]
# ### Feature Importance
#
# - **total_rooms**, **total_bedrooms**,**population**,**household** seem to be important features due to their strong correlation with multiple features

# %%
housing_df['cost_per_square_feet'] = housing_df['median_house_value'] / housing_df['total_rooms']
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
sorted_df = housing_df.sort_values(by=['median_house_value'], ascending=False)
sorted_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10667    -117.88     33.55                  27         2278           316.0
# 16916    -122.34     37.57                  52         2635           408.0
# 16946    -122.33     37.55                  33         2199           312.0
# 8877     -118.49     34.04                  48         2381           345.0
# 8878     -118.50     34.04                  52         3000           374.0
# ...          ...       ...                 ...          ...             ...
# 5887     -118.33     34.15                  39          493           168.0
# 9188     -117.86     34.24                  52          803           267.0
# 2521     -122.74     39.71                  16          255            73.0
# 2799     -117.02     36.40                  19          619           239.0
# 19802    -123.17     40.31                  36           98            28.0
#
# ...

# %%
top_10_percent_count = int(len(sorted_df) * 0.1)
top_10_percent_df = sorted_df.head(top_10_percent_count)
top_10_percent_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10667    -117.88     33.55                  27         2278           316.0
# 16916    -122.34     37.57                  52         2635           408.0
# 16946    -122.33     37.55                  33         2199           312.0
# 8877     -118.49     34.04                  48         2381           345.0
# 8878     -118.50     34.04                  52         3000           374.0
# ...          ...       ...                 ...          ...             ...
# 15368    -117.17     33.28                  16         1921           312.0
# 16956    -122.30     37.53                  38          984           171.0
# 6383     -118.05     34.16                  36         3908           732.0
# 15254    -117.27     33.02                  13         5723          1242.0
# 15804    -122.44     37.76                  50         2589           569.0
#
# ...

# %%
def premium_box_plot(x_val,y_val):
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=x_val, y=y_val, data=top_10_percent_df)
    plt.title(f"{y_val} vs {x_val}")
    plt.xlabel(x_val)
    plt.ylabel(y_val)
    plt.show()

# %%
premium_box_plot('ocean_proximity','median_house_value')

# %%
premium_box_plot('cost_per_square_feet','median_house_value')

# %%
premium_box_plot('median_income','median_house_value')

# %%
def visualize_column_distribution(column_name):  
    fig,axes = plt.subplots(1, 3, figsize=(18, 6))
    
    sns.kdeplot(housing_df[column_name], ax=axes[0], fill=False)
    axes[0].set_title(f'KDE of {column_name}')
    axes[0].set_xlabel(column_name)
    axes[0].set_ylabel('Density')
    
    sns.boxplot(data= housing_df, x=column_name, ax=axes[1])
    axes[1].set_title(f'Boxplot of {column_name}')
    axes[1].set_xlabel(column_name)
    
    sns.scatterplot(data=housing_df,x=column_name, y='median_house_value', ax=axes[2])
    axes[2].set_title(f'{column_name} vs median house value')
    axes[2].set_xlabel(column_name)
    axes[2].set_ylabel('median house value')

    plt.tight_layout()
    plt.show()

# %%
visualize_column_distribution('total_bedrooms')

# %%
def visualize_outliers_based_on_std(housing_df, column_name):    
    mean = housing_df[column_name].mean()
    std_dev = housing_df[column_name].std()
    
    lower_bound = mean - 2 * std_dev
    upper_bound = mean + 2 * std_dev
    
    outliers = housing_df[(housing_df[column_name] < lower_bound) | (housing_df[column_name] > upper_bound)]
    num_outliers = outliers.shape[0]
    
    print(f"Total number of outliers in '{column_name}': {num_outliers}")
    
    plt.figure(figsize=(12, 6))
    plt.hist(housing_df[column_name], bins=50, color='blue', alpha=0.5, edgecolor='black')
    plt.axvspan(housing_df[column_name].min(), lower_bound, color='red', alpha=0.3)
    plt.axvspan(upper_bound, housing_df[column_name].max(), color='red', alpha=0.3)
    plt.title(f'Outlier Detection in {column_name} (95% Interval)')
    plt.xlabel(column_name)
    plt.ylabel('Density')
    plt.legend()
    plt.show()

# %%
visualize_outliers_based_on_std(housing_df, 'median_house_value')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Total number of outliers in 'median_house_value': 1383

# %%
x = housing_df.drop(['median_house_value'] , axis = 1).values
y = housing_df['median_house_value' ].values

# %%
mm_scaler = MinMaxScaler()
x_mm = mm_scaler.fit_transform(x)
x_mm
# Out:
# array([[2.11155378e-01, 5.67481403e-01, 7.84313725e-01, ...,
#         5.39668418e-01, 7.50000000e-01, 7.45795834e-03],
#        [2.12151394e-01, 5.65356004e-01, 3.92156863e-01, ...,
#         5.38027062e-01, 7.50000000e-01, 7.11356517e-04],
#        [2.10159363e-01, 5.64293305e-01, 1.00000000e+00, ...,
#         4.66028055e-01, 7.50000000e-01, 3.46798140e-03],
#        ...,
#        [3.11752988e-01, 7.32199787e-01, 3.13725490e-01, ...,
#         8.27643757e-02, 2.50000000e-01, 5.72434789e-04],
#        [3.01792829e-01, 7.32199787e-01, 3.33333333e-01, ...,
#         9.42952511e-02, 2.50000000e-01, 6.39173954e-04],
#        [3.09760956e-01, 7.25823592e-01, 2.94117647e-01, ...,
#         1.30253376e-01, 2.50000000e-01, 4.43720752e-04]])

# %%
s_scaler = StandardScaler()
x_s = s_scaler.fit_transform(x)
x_s
# Out:
# array([[-1.32783522,  1.05254828,  0.98214266, ...,  2.34476576,
#          1.2910888 ,  0.42931421],
#        [-1.32284391,  1.04318455, -0.60701891, ...,  2.33223796,
#          1.2910888 , -0.12535301],
#        [-1.33282653,  1.03850269,  1.85618152, ...,  1.7826994 ,
#          1.2910888 ,  0.101281  ],
#        ...,
#        [-0.8237132 ,  1.77823747, -0.92485123, ..., -1.14259331,
#         -0.11673923, -0.13677437],
#        [-0.87362627,  1.77823747, -0.84539315, ..., -1.05458292,
#         -0.11673923, -0.13128745],
#        [-0.83369581,  1.75014627, -1.00430931, ..., -0.78012947,
#         -0.11673923, -0.1473565 ]])

# %%
y
# Out:
# array([452600, 358500, 352100, ...,  92300,  84700,  89400])

# %%
values_1 = np.array(x_mm)
print(f"For min max {np.min(values_1),np.max(values_1)}")
# Out:
# For min max (0.0, 1.0)

# %%
values_2 = np.array(x_s)
print(f"For standard {np.min(values_2),np.max(values_2)}")
# Out:
# For standard (-2.3859923416733877, 82.03047550299351)

# %% [markdown]
# ### Resulting ranges
#
# - **Min Max Scaling** - Transforms features to range [0, 1].
#
# - **Standard Scaling** - Transforms features to have a mean of 0 and standard deviation of 1

# %% [markdown]
# ### Min Max Scaling
#
# **Benefits:**
# - All features are on the same scale
# - Simple to implement and understand
#
# **Drawbacks:**
# -  Sensitive to outliers

# %% [markdown]
# ### Standard Scaling
#
# **Benefits:**
# - Not affected by outliers as much as Min-Max scaling, since it focuses on the mean and standard deviation
# - Suitable for algorithms that assume normal distribution
#
# **Drawbacks:**
# - Extreme outliers can affect

# %% [markdown]
# ### More Methods
#
# - **RobustScaler** - ideal for data with many outliers.
#
# - **QuantileTransformer** - to transform the data to a uniform or normal distribution.
#
# - **PowerTransformer** - make data more Gaussian-like, mainly for models assuming normality.
